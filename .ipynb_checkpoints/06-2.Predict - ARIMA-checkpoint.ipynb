# %% [markdown]
# <br>
# # ** 6 ARIMA Analysis**
# 통계를 활용한 시계열 데이터 분석

# %% [markdown]
# <br><br>
# ## **ARIMA 시계열 분석을 활용한 주가예측**

# %% [markdown]
# ### **1 시계열 데이터의 AR, MA 특성 찾기**
# 1. **AR(자기회귀)의 특성**
# 1. **MA(이동평균)의 특성**

# %%
from pandas_datareader import get_data_yahoo
stock = get_data_yahoo('KO', '2016-07-01', '2016-12-31')
price = stock.Close
stock.tail(3)
# import numpy as np
# price_array = np.asarray(price)
# price_array.shape
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2016-12-28  41.669998  41.389999  41.490002  41.389999   8988000.0  39.693062
# 2016-12-29  41.689999  41.380001  41.380001  41.599998   6817900.0  39.894455
# 2016-12-30  41.840000  41.349998  41.689999  41.459999  11470200.0  39.760189

# %% [markdown]
# <br>
# ### ** 01-1. ACF & PACF Plots**

# %%
# %matplotlib inline
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plot_acf(price)
plt.show()

# %%
plot_pacf(price)
plt.show()

# %% [markdown]
# <br>
# ### ** 01-2. ACF & PACF Plots 2**

# %%
diff_1 = price.diff(periods=1).dropna()
plot_acf(diff_1)
plt.show()

# %%
plot_pacf(diff_1)
plt.show()

# %% [markdown]
# <br>
# ## ** 2 ARIMA 모형 만들고 평가하기**
# 통계적 검정

# %% [markdown]
# ### **01 선형 모델의 해석**
# **OLS**

# %%
from sklearn.datasets import load_iris 
data = load_iris()

import pandas as pd
df = pd.DataFrame(data.data)
df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
df['class'] = [data.target_names[no]   for no in data.target]
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width   class
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
# Setosa 품종의 꽃받침 길이와 너비관계를 선형회귀 모델을 만든다
# %matplotlib inline

import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(7,7))
ax.scatter(df['sepal_width'][:50], df['sepal_length'][:50])
ax.set_ylabel('Sepal Length')
ax.set_xlabel('Sepal Width')
ax.set_title('Setosa Sepal Width vs. Sepal Length', fontsize=14, y=1.2)
# Out:
# Text(0.5,1.2,'Setosa Sepal Width vs. Sepal Length')

# %%
# 데이터 분포를 살펴본결과 선형을 볼 수 있다
# statsmodels 을 사용하여 선형회귀 모델로 검증한다
import statsmodels.api as sm

y = df['sepal_length'][:50]
x = df['sepal_width'][:50]
X = sm.add_constant(x)
results = sm.OLS(y, X).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           sepal_length   R-squared:                       0.558
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     60.52
# Date:                Wed, 06 Jun 2018   Prob (F-statistic):           4.75e-10
# Time:                        15:55:12   Log-Likelihood:                 2.0879
# No. Observations:                  50   AIC:                           -0.1759
# Df Residuals:                      48   BIC:                             3.648
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           2.6447      0.305      8.660      0.000       2.031       3.259
# sepal_width     0.6909      0.089      7.779      0.000       0.512       0.869
# ==============================================================================
# Omnibus:                        0.252   Durbin-Watson:                   2.517
# Prob(Omnibus):                  0.882   Jarque-Bera (JB):                0.436
# Skew:                          -0.110   Prob(JB):                        0.804
# Kurtosis:                       2.599   Cond. No.                         34.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### **02 ARMA 모델의 해석**
# **ARMA**

# %%
price.plot()

# %%
import warnings
warnings.filterwarnings("ignore")

import statsmodels.tsa.api as tsa
ARMA = tsa.ARMA(price, order =(2, 2))
ARMA_results= ARMA.fit()
ARMA_results.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                            Results: ARMA
# ====================================================================
# Model:              ARMA             BIC:                 141.6145
# Dependent Variable: Close            Log-Likelihood:      -56.251
# Date:               2018-06-06 16:00 Scale:               1.0000
# No. Observations:   128              Method:              css-mle
# Df Model:           5                Sample:              06-30-2016
# Df Residuals:       123                                   12-30-2016
# Converged:          0.0000           S.D. of innovations: 0.365
# AIC:                124.5023         HQIC:                131.455
# ---------------------------------------------------------------------
#                Coef.   Std.Err.      t       P>|t|    [0.025   0.975]
# ---------------------------------------------------------------------
# const         38.4255    2.0387     18.8483  0.0000  34.4298  42.4212
# ar.L1.Close    1.9990    0.0002   8101.0999  0.0000   1.9985   1.9995
# ar.L2.Close   -0.9990    0.0003  -3572.3518  0.0000  -0.9996  -0.9985
# ma.L1.Close   -1.1522    0.0978    -11.7781  0.0000  -1.3439  -0.9605
# ma.L2.Close    0.1522    0.0976      1.5587  0.1216  -0.0392   0.3436
# -----------------------------------------------------------------------------
#                  Real           Imaginary          Modulus          Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0005            -0.0056           1.0005            -0.0009
# AR.2            1.0005             0.0056           1.0005             0.0009
# MA.1            1.0000             0.0000           1.0000             0.0000
# MA.2            6.5707             0.0000           6.5707             0.0000
# ====================================================================
#
# """

# %% [markdown]
# ### **03 ARIMA 모델의 해석**
# **ARIMA**

# %%
from statsmodels.tsa.arima_model import ARIMA

model     = ARIMA (price, order = (0, 1, 1))
model_fit = model.fit(trend = 'c', full_output = True, disp = 1)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Close   No. Observations:                  331
# Model:                 ARIMA(0, 1, 1)   Log Likelihood               -2675.741
# Method:                       css-mle   S.D. of innovations            784.359
# Date:                Tue, 15 May 2018   AIC                           5357.481
# Time:                        11:27:55   BIC                           5368.888
# Sample:                    01-03-2017   HQIC                          5362.031
#                          - 05-15-2018
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            40.3323     45.103      0.894      0.372     -48.068     128.732
# ma.L1.D.Close     0.0463      0.055      0.835      0.404      -0.062       0.155
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1          -21.5934           +0.0000j           21.5934            0.5000
# -----------------------------------------------------------------------------

# %%
model = ARIMA(price, order = (0,1,3))
model_fit = model.fit(trend = 'c', full_output = True, disp = 1)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Close   No. Observations:                  331
# Model:                 ARIMA(0, 1, 3)   Log Likelihood               -2675.174
# Method:                       css-mle   S.D. of innovations            783.006
# Date:                Tue, 15 May 2018   AIC                           5360.349
# Time:                        11:27:55   BIC                           5379.359
# Sample:                    01-03-2017   HQIC                          5367.931
#                          - 05-15-2018
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            40.8201     41.462      0.985      0.326     -40.444     122.084
# ma.L1.D.Close     0.0334      0.056      0.601      0.548      -0.076       0.143
# ma.L2.D.Close    -0.0097      0.061     -0.159      0.874      -0.130       0.111
# ma.L3.D.Close    -0.0609      0.059     -1.037      0.301      -0.176       0.054
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            2.5597           -0.0000j            2.5597           -0.0000
# MA.2           -1.3598           -2.1363j            2.5323           -0.3402
# MA.3           -1.3598           +2.1363j            2.5323            0.3402
# -----------------------------------------------------------------------------

# %%
model_fit.plot_predict()
plt.grid()
plt.show()

# %%
fore = model_fit.forecast(steps = 10)
print('주가예측 : {} \nstderr : {} \nupper bound : {} \nlower bound : {}'.format(
    fore[0], 
    fore[1][0], 
    fore[2][0][0], 
    fore[2][0][1]))

pd.Series(fore[0]).plot(figsize=(16,2), grid=True)
# Out:
# 주가예측 : [49503.95769355 49631.82392976 49709.78377326 49750.60389034
#  49791.42400743 49832.24412451 49873.0642416  49913.88435868
#  49954.70447577 49995.52459285]
# stderr : 783.006155256694
# upper bound : 47969.2938295694
# lower bound : 51038.62155752199
